# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8d6fbe2e-6836-4008-b370-e6a790545302" name="files[]" multiple disabled />
#      <output id="result-8d6fbe2e-6836-4008-b370-e6a790545302">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving House-Price.csv to House-Price (1).csv
# ...

# %%
df=pd.read_csv('House-Price.csv')
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %% [markdown]
# **#EDD**

# %%
import seaborn as sns
sns.set(style="darkgrid")

# %%
sns.pairplot(data=df,size=2.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.jointplot(x='crime_rate',y='price',data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.jointplot(x='rainfall',y='price',data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.jointplot(x='air_qual',y='price',data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.countplot(x='rainfall',data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %% [markdown]
# #Observation
# 1. Outlier in rainfall and n_hos_rooms
# 2. Missing value in n_hos_beds
# 3. bus_ter have only yes value
# 4. Skewness or outlier on crimerate **bold text**

# %%
uv=np.percentile(df.n_hot_rooms,[99])[0]
print(uv)
# Out:
# 15.399519999999999

# %%
df[df.n_hot_rooms>uv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
#remove outlier like 101.12 and 81.12 and mor........
df.n_hot_rooms[(df.n_hot_rooms>3*uv)]=3*uv
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lv=np.percentile(df.rainfall,[1])[0]
lv
# Out:
# 20.0

# %%
df[df.rainfall<lv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
df.rainfall[(df.rainfall<0.3*lv)]=0.3*lv
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.jointplot(x='crime_rate',y='price',data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
#fill na value with mean 
df.n_hos_beds= df.n_hos_beds.fillna(df.n_hos_beds.mean)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     506 non-null object
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(14), int64(1), object(4)
# memory usage: 75.2+ KB

# %%
sns.jointplot(x='crime_rate',y='price',data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#we found log value of crime rate then relation of crimerate and price is more linear
df.crime_rate=np.log(1+df.crime_rate)

# %%
sns.jointplot(x='crime_rate',y='price',data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
df['avg_dist']=(df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df.drop(df.columns[6:10], axis=1, inplace=True)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hot_rooms    rainfall       parks    avg_dist
# count  506.000000  506.000000   506.000000  506.000000  506.000000  506.000000
# mean    21.544466   12.653063    12.864050   39.187747    0.054454    3.795104
# ...

# %%
#remove not usefull variable
del df['bus_ter']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.48     11.19200     River        23  0.049347
# 1       9.14      NO      7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO      7.394     46.19856      None        38  0.045764
# 3       2.94     YES      9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO      8.824     11.28960      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.48     11.19200     River        23  0.049347
# 1       9.14      NO      7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO      7.394     46.19856      None        38  0.045764
# 3       2.94     YES      9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO      8.824     11.28960      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
df=pd.get_dummies(df, columns=["airport"])

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop n_hos_beds  n_hot_rooms waterbody  rainfall     parks  avg_dist  \
# 0       4.98       5.48     11.19200     River        23  0.049347    4.0875
# 1       9.14      7.332     12.17280      Lake        42  0.046146    4.9675
# 2       4.03      7.394     46.19856      None        38  0.045764    4.9675
# 3       2.94      9.268     11.26720      Lake        45  0.047151    6.0650
# 4       5.33      8.824     11.28960      Lake        55  0.039474    6.0625
#
#    airport_NO  airport_YES
# 0           0            1
# 1           1            0
# ...

# %%
df=pd.get_dummies(df, columns=["waterbody"])

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.48     11.19200        23  0.049347    4.0875
# 1       9.14      7.332     12.17280        42  0.046146    4.9675
# 2       4.03      7.394     46.19856        38  0.045764    4.9675
# 3       2.94      9.268     11.26720        45  0.047151    6.0650
# 4       5.33      8.824     11.28960        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# 0           0            1               0                         0
# ...

# %%
#delete airport_NO and water_body none variable
del df['airport_NO']

# %%
del df['waterbody_None']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.48     11.19200        23  0.049347    4.0875
# 1       9.14      7.332     12.17280        42  0.046146    4.9675
# 2       4.03      7.394     46.19856        38  0.045764    4.9675
# 3       2.94      9.268     11.26720        45  0.047151    6.0650
# 4       5.33      8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
#get high correlation cofficient variable to analysis(near of 1)
del df['parks']
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# avg_dist                  0.249289   -0.586371   -0.708022 -0.769247
# airport_YES               0.182867   -0.134486   -0.115401 -0.073903
# waterbody_Lake            0.036233   -0.025390   -0.026590 -0.046393
# ...

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.48     11.19200        23    4.0875            1
# 1       9.14      7.332     12.17280        42    4.9675            0
# 2       4.03      7.394     46.19856        38    4.9675            0
# 3       2.94      9.268     11.26720        45    6.0650            1
# 4       5.33      8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River
# 0               0                         0                1
# ...

# %%
import statsmodels.api as sn

# %%
#fit model using stat
X=sn.add_constant(df['room_num'])

# %%
lm=sn.OLS(df['price'],X).fit()

# %%
lm.params
# Out:
# const      -34.659243
# room_num     9.099670
# dtype: float64

# %%
lm.tvalues
# Out:
# const      -13.117889
# room_num    21.779230
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Tue, 19 Mar 2019   Prob (F-statistic):           1.31e-74
# Time:                        07:28:55   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %%
 #regression model using sklearn
from sklearn.linear_model import LinearRegression

# %%
y=df['price']
X=df[['room_num']]

# %%
lm2=LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(lm2.intercept_,'\n',lm2.coef_)
# Out:
# -34.65924312309717
#  [9.09966966]

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model.base object:
#
# class LinearRegression(LinearModel, sklearn.base.RegressorMixin)
#  |  Ordinary least squares Linear Regression.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : boolean, optional, default True
#  |      whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (e.g. data is expected to be already centered).
#  |
#  |  normalize : boolean, optional, default False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
#  |      If True, the regressors X will be normalized before regression by
#  |      subtracting the mean and dividing by the l2-norm.
#  |      If you wish to standardize, please use
#  |      :class:`sklearn.preprocessing.StandardScaler` before calling ``fit`` on
#  |      an estimator with ``normalize=False``.
#  |
#  |  copy_X : boolean, optional, default True
# ...

# %% [markdown]
# #Multiple Linear

# %%
X_multi=df.drop(['price', 'n_hos_beds'],axis=1)

# %%
X_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hot_rooms  rainfall  avg_dist  airport_YES  waterbody_Lake  \
# 0     11.19200      23.0    4.0875            1               0
# 1     12.17280      42.0    4.9675            0               1
# 2     46.19856      38.0    4.9675            0               0
# 3     11.26720      45.0    6.0650            1               1
# 4     11.28960      55.0    6.0625            0               1
#
#    waterbody_Lake and River  waterbody_River
# 0                         0                1
# 1                         0                0
# ...

# %%
y_multi=df.price

# %%
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %%
#add constant to our dependent variable
X_multi_cons=sn.add_constant(X_multi)
X_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1    1.0    0.026944       37.07     0.469     6.421  78.9      22.2
# 2    1.0    0.026924       37.07     0.469     7.185  61.1      22.2
# 3    1.0    0.031857       32.18     0.458     6.998  45.8      21.3
# 4    1.0    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hot_rooms  rainfall  avg_dist  airport_YES  waterbody_Lake  \
# 0       4.98     11.19200      23.0    4.0875            1               0
# 1       9.14     12.17280      42.0    4.9675            0               1
# 2       4.03     46.19856      38.0    4.9675            0               0
# 3       2.94     11.26720      45.0    6.0650            1               1
# 4       5.33     11.28960      55.0    6.0625            0               1
#
#    waterbody_Lake and River  waterbody_River
# 0                         0                1
# ...

# %%
type(df.room_num)
# Out:
# pandas.core.series.Series

# %%
df.info()
#lm_multi=sn.OLS(y_multi.astype(float),X_multi_cons.astype(float)).fit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 16 columns):
# price                       506 non-null float64
# crime_rate                  506 non-null float64
# resid_area                  506 non-null float64
# air_qual                    506 non-null float64
# room_num                    506 non-null float64
# age                         506 non-null float64
# teachers                    506 non-null float64
# poor_prop                   506 non-null float64
# n_hos_beds                  506 non-null object
# n_hot_rooms                 506 non-null float64
# rainfall                    506 non-null float32
# avg_dist                    506 non-null float64
# airport_YES                 506 non-null uint8
# waterbody_Lake              506 non-null uint8
# waterbody_Lake and River    506 non-null uint8
# waterbody_River             506 non-null uint8
# dtypes: float32(1), float64(10), object(1), uint8(4)
# memory usage: 47.5+ KB

# %%
print(df.dtypes)
# Out:
# price                       float64
# crime_rate                  float64
# resid_area                  float64
# air_qual                    float64
# room_num                    float64
# age                         float64
# teachers                    float64
# poor_prop                   float64
# n_hos_beds                   object
# n_hot_rooms                 float64
# rainfall                    float32
# avg_dist                    float64
# airport_YES                   uint8
# waterbody_Lake                uint8
# waterbody_Lake and River      uint8
# waterbody_River               uint8
# dtype: object

# %%
cols = df.select_dtypes(exclude=['float']).columns

df[cols] = df[cols].apply(pd.to_numeric, downcast='float', errors='coerce')

# %%
print(df.dtypes)
# Out:
# price                       float64
# crime_rate                  float64
# resid_area                  float64
# air_qual                    float64
# room_num                    float64
# age                         float64
# teachers                    float64
# poor_prop                   float64
# n_hos_beds                   object
# n_hot_rooms                 float64
# rainfall                    float32
# avg_dist                    float64
# airport_YES                   uint8
# waterbody_Lake                uint8
# waterbody_Lake and River      uint8
# waterbody_River               uint8
# dtype: object

# %%
 lm_multi=sn.OLS(y_multi,X_multi_cons).fit()

# %%
lm_multi.params
# Out:
# const                       -3.391541
# crime_rate                   0.046662
# resid_area                  -0.036018
# air_qual                   -16.778779
# room_num                     4.000614
# age                         -0.005901
# teachers                     1.010197
# poor_prop                   -0.585769
# n_hot_rooms                  0.089638
# rainfall                     0.018566
# avg_dist                    -1.255424
# airport_YES                  1.125961
# waterbody_Lake               0.302120
# waterbody_Lake and River    -0.631369
# waterbody_River             -0.346324
# dtype: float64

# %%
lm_multi.pvalues
# Out:
# const                       5.049480e-01
# crime_rate                  8.937119e-01
# resid_area                  5.331611e-01
# air_qual                    3.212101e-05
# room_num                    3.231480e-19
# age                         6.658847e-01
# teachers                    1.539166e-15
# poor_prop                   1.018405e-25
# n_hot_rooms                 2.776327e-01
# rainfall                    2.993290e-01
# avg_dist                    7.971736e-11
# airport_YES                 1.387121e-02
# waterbody_Lake              6.392474e-01
# waterbody_Lake and River    3.784605e-01
# waterbody_River             5.277739e-01
# dtype: float64

# %%
lm_multi.predict
# Out:
# <bound method Results.predict of <statsmodels.regression.linear_model.OLSResults object at 0x7fa82221b0f0>>

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     89.36
# Date:                Tue, 19 Mar 2019   Prob (F-statistic):          4.35e-125
# Time:                        09:40:39   Log-Likelihood:                -1519.0
# No. Observations:                 506   AIC:                             3068.
# Df Residuals:                     491   BIC:                             3131.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
lm3=LinearRegression()
lm3.fit(X_multi,y_multi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(lm3.coef_,'\n',lm3.intercept_)
# Out:
# [ 4.66622911e-02 -3.60184628e-02 -1.67787792e+01  4.00061407e+00
#  -5.90066504e-03  1.01019671e+00 -5.85769146e-01  8.96378885e-02
#   1.85655677e-02 -1.25542409e+00  1.12596129e+00  3.02119839e-01
#  -6.31368633e-01 -3.46324263e-01]
#  -3.3915409951000797

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (404, 1) (102, 1) (404,) (102,)

# %%
lm_a=LinearRegression()

# %%
lm_a.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_test_a=lm_a.predict(X_test)

# %%
y_train_a=lm_a.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.4247499635222679

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.4983517715400687

# %%
from sklearn import preprocessing

# %%
scaler=preprocessing.StandardScaler().fit(X_train)

# %%
X_train_s=scaler.transform(X_train)

# %%
X_test_s=scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
lm_r=Ridge(alpha=0.5)
lm_r.fit(X_train_s,y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
r2_score(y_test,lm_r.predict(X_test_s))
# Out:
# 0.424951384101385

# %%
from sklearn.model_selection import  validation_curve

# %%
validation_curve?

# %%
param_range=np.logspace(-2,8,100)

# %%
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores,test_scores=validation_curve(Ridge(),X_train_s,y_train,'alpha',param_range,scoring='r2')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
print(train_scores,'\nTest Score',test_scores)
# Out:
# [[4.88654957e-01 5.45689029e-01 4.64718883e-01]
#  [4.88654957e-01 5.45689029e-01 4.64718882e-01]
#  [4.88654957e-01 5.45689028e-01 4.64718882e-01]
#  [4.88654956e-01 5.45689027e-01 4.64718881e-01]
#  [4.88654955e-01 5.45689025e-01 4.64718879e-01]
#  [4.88654953e-01 5.45689021e-01 4.64718876e-01]
#  [4.88654949e-01 5.45689016e-01 4.64718872e-01]
#  [4.88654944e-01 5.45689007e-01 4.64718865e-01]
#  [4.88654937e-01 5.45688993e-01 4.64718854e-01]
#  [4.88654924e-01 5.45688971e-01 4.64718836e-01]
#  [4.88654904e-01 5.45688936e-01 4.64718808e-01]
#  [4.88654872e-01 5.45688881e-01 4.64718763e-01]
#  [4.88654821e-01 5.45688792e-01 4.64718692e-01]
#  [4.88654739e-01 5.45688651e-01 4.64718579e-01]
#  [4.88654610e-01 5.45688427e-01 4.64718399e-01]
#  [4.88654404e-01 5.45688070e-01 4.64718112e-01]
#  [4.88654077e-01 5.45687503e-01 4.64717656e-01]
#  [4.88653556e-01 5.45686600e-01 4.64716931e-01]
#  [4.88652728e-01 5.45685165e-01 4.64715778e-01]
#  [4.88651411e-01 5.45682884e-01 4.64713946e-01]
# ...

# %%
train_mean=np.mean(train_scores,axis=1)
train_mean
# Out:
# array([4.99687623e-01, 4.99687623e-01, 4.99687622e-01, 4.99687621e-01,
#        4.99687619e-01, 4.99687617e-01, 4.99687612e-01, 4.99687605e-01,
#        4.99687595e-01, 4.99687577e-01, 4.99687549e-01, 4.99687505e-01,
#        4.99687435e-01, 4.99687323e-01, 4.99687145e-01, 4.99686862e-01,
#        4.99686412e-01, 4.99685696e-01, 4.99684557e-01, 4.99682747e-01,
#        4.99679871e-01, 4.99675306e-01, 4.99668061e-01, 4.99656577e-01,
#        4.99638395e-01, 4.99609649e-01, 4.99564283e-01, 4.99492856e-01,
#        4.99380719e-01, 4.99205300e-01, 4.98932116e-01, 4.98509045e-01,
#        4.97858351e-01, 4.96866026e-01, 4.95368355e-01, 4.93136367e-01,
#        4.89860277e-01, 4.85138172e-01, 4.78475782e-01, 4.69306293e-01,
#        4.57038858e-01, 4.41139676e-01, 4.21238929e-01, 3.97242702e-01,
#        3.69417446e-01, 3.38413980e-01, 3.05213045e-01, 2.71000485e-01,
#        2.37004827e-01, 2.04340749e-01, 1.73894538e-01, 1.46268486e-01,
# ...

# %%
test_mean=np.mean(test_scores,axis=1)
test_mean
# Out:
# array([ 4.67629253e-01,  4.67629935e-01,  4.67630796e-01,  4.67631881e-01,
#         4.67633251e-01,  4.67634979e-01,  4.67637158e-01,  4.67639906e-01,
#         4.67643370e-01,  4.67647737e-01,  4.67653240e-01,  4.67660173e-01,
#         4.67668902e-01,  4.67679887e-01,  4.67693702e-01,  4.67711060e-01,
#         4.67732844e-01,  4.67760143e-01,  4.67794290e-01,  4.67836903e-01,
#         4.67889917e-01,  4.67955615e-01,  4.68036621e-01,  4.68135842e-01,
#         4.68256320e-01,  4.68400916e-01,  4.68571727e-01,  4.68769076e-01,
#         4.68989848e-01,  4.69224819e-01,  4.69454548e-01,  4.69643241e-01,
#         4.69729946e-01,  4.69616473e-01,  4.69151808e-01,  4.68113628e-01,
#         4.66189154e-01,  4.62960066e-01,  4.57899232e-01,  4.50389480e-01,
#         4.39774461e-01,  4.25446272e-01,  4.06962680e-01,  3.84170857e-01,
#         3.57301750e-01,  3.26998826e-01,  2.94261712e-01,  2.60313959e-01,
# ...

# %%
max(test_mean)
# Out:
# 0.46972994579494404

# %%
sns.jointplot(x=np.log(param_range),y=test_mean)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
np.where(test_mean==max(test_mean))
# Out:
# (array([32]),)

# %%
param_range[32]
# Out:
# 17.073526474706906

# %%
lm_r_best=Ridge(alpha=param_range[32])

# %%
lm_r_best.fit(X_train_s,y_train)
# Out:
# Ridge(alpha=17.073526474706906, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001)

# %%
r2_score(y_test,lm_r_best.predict(X_test_s))
# Out:
# 0.43041743518069675

# %%
r2_score(y_train,lm_r_best.predict(X_train_s))
# Out:
# 0.49753242693963284

# %%
from sklearn.linear_model import Lasso
